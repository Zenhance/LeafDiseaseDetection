# %%
import os
import glob
import h5py
import shutil
import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mimg
from os import listdir, makedirs, getcwd, remove
from os.path import isfile, join, abspath, exists, isdir, expanduser
from PIL import Image
from pathlib import Path
from skimage.io import imread
from skimage.transform import resize
from keras.models import Sequential, Model
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from keras.layers import GlobalMaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.merge import Concatenate
from keras.models import Model
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
import cv2
from keras import backend as K

# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt

from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras_preprocessing.image import ImageDataGenerator


dir = "E:\Design Project Dataset\Grape Dataset"

train_dir = os.path.join(dir, 'train')
test_dir = os.path.join(dir, 'test')

CATEGORIES = ['Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___healthy', 'Grape___healthy']

train_dataset_size = 0
test_dataset_size = 0

for i in CATEGORIES:
    train_dataset_size += len(os.listdir(os.path.join(train_dir, i)))
    test_dataset_size += len(os.listdir(os.path.join(test_dir, i)))


train_image_generator = ImageDataGenerator(rescale=1./255, rotation_range=45, width_shift_range=.15, height_shift_range=.15, horizontal_flip=True, zoom_range=0.5)
validation_image_generator = ImageDataGenerator(rescale=1./255)

training_datagen = train_image_generator.flow_from_directory(batch_size=16, directory=train_dir, shuffle=True, target_size=(256, 256), class_mode='sparse')

testing_datagen = validation_image_generator.flow_from_directory(batch_size=16, directory=test_dir, shuffle=True, target_size=(256, 256), class_mode='sparse')
# Out:
# Found 3663 images belonging to 4 classes.
# Found 400 images belonging to 4 classes.

# %%
def build_model():
    input_img = Input(shape=(256,256,3), name='ImageInput')
    x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv1_1')(input_img)
    x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv1_2')(x)
    x = MaxPooling2D((2,2), name='pool1')(x)

    x = SeparableConv2D(128, (3,3), activation='relu', padding='same', name='Conv2_1')(x)
    x = SeparableConv2D(128, (3,3), activation='relu', padding='same', name='Conv2_2')(x)
    x = MaxPooling2D((2,2), name='pool2')(x)

    x = SeparableConv2D(256, (3,3), activation='relu', padding='same', name='Conv3_1')(x)
    x = BatchNormalization(name='bn1')(x)
    x = SeparableConv2D(256, (3,3), activation='relu', padding='same', name='Conv3_2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = SeparableConv2D(256, (3,3), activation='relu', padding='same', name='Conv3_3')(x)
    x = MaxPooling2D((2,2), name='pool3')(x)

    x = SeparableConv2D(512, (3,3), activation='relu', padding='same', name='Conv4_1')(x)
    x = BatchNormalization(name='bn3')(x)
    x = SeparableConv2D(128, (3,3), activation='relu', padding='same', name='Conv4_2')(x)
    x = BatchNormalization(name='bn4')(x)
    x = SeparableConv2D(64, (3,3), activation='relu', padding='same', name='Conv4_3')(x)
    x = MaxPooling2D((2,2), name='pool4')(x)

    x = Flatten(name='flatten')(x)
    x = Dense(64, activation='relu', name='fc1')(x)
    x = Dropout(0.7, name='dropout1')(x)
    x = Dense(32, activation='relu', name='fc2')(x)
    x = Dropout(0.5, name='dropout2')(x)
    x = Dense(4, activation='softmax', name='fc3')(x)

    model = Model(inputs=input_img, outputs=x)
    return model

# %%
def build_small_model():
    input_img = Input(shape=(256,256,3), name='ImageInput')
    x = Conv2D(64,(3,3),activation='relu',padding='same',name='Conv1')(input_img)
    x = BatchNormalization(name='bn1')(x)
    x = MaxPooling2D((2,2),name='pool1')(x)

    x= SeparableConv2D(128,(3,3),activation='relu',padding='same',name='Conv2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = MaxPooling2D((2,2), name='pool2')(x)

    x = SeparableConv2D(256,(3,3),activation='relu',padding='same',name='Conv3')(x)

    x = SeparableConv2D(256,(3,3), activation='relu',padding='same', name='Conv4')(x)

    x = SeparableConv2D(256,(3,3), activation='relu', padding='same', name='Conv5')(x)
    x = MaxPooling2D((2,2), name='pool3')(x)

    x = Flatten(name='flatten')(x)
    x = Dense(64,activation='relu',name='fc1')(x)
    x = Dense(32,activation='relu',name='fc2')(x)
    x = Dense(4,activation='softmax',name='fc3')(x)

    small_model = Model(inputs=input_img, outputs=x)

    return small_model

# %%
model =  build_small_model()
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# ImageInput (InputLayer)      [(None, 256, 256, 3)]     0
# _________________________________________________________________
# Conv1 (Conv2D)               (None, 256, 256, 64)      1792
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 256, 256, 64)      256
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 128, 128, 64)      0
# _________________________________________________________________
# Conv2 (SeparableConv2D)      (None, 128, 128, 128)     8896
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 128, 128, 128)     512
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 64, 64, 128)       0
# _________________________________________________________________
# Conv3 (SeparableConv2D)      (None, 64, 64, 256)       34176
# _________________________________________________________________
# Conv4 (SeparableConv2D)      (None, 64, 64, 256)       68096
# _________________________________________________________________
# Conv5 (SeparableConv2D)      (None, 64, 64, 256)       68096
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 32, 32, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 262144)            0
# _________________________________________________________________
# fc1 (Dense)                  (None, 64)                16777280
# _________________________________________________________________
# fc2 (Dense)                  (None, 32)                2080
# _________________________________________________________________
# fc3 (Dense)                  (None, 4)                 132
# =================================================================
# Total params: 16,961,316
# Trainable params: 16,960,932
# Non-trainable params: 384
# _________________________________________________________________

# %%
# Open the VGG16 weight file
f = keras.applications.InceptionV3(weights='imagenet', include_top=True)

# %%
# Select the layers for which you want to set weight.

#w,b = f['block1_conv1']['block1_conv1_W_1:0'], f['block1_conv1']['block1_conv1_b_1:0']
model.layers[1].set_weights = f.layers[1].output

#w,b = f['block1_conv2']['block1_conv2_W_1:0'], f['block1_conv2']['block1_conv2_b_1:0']
model.layers[2].set_weights = f.layers[4].output

#w,b = f['block2_conv1']['block2_conv1_W_1:0'], f['block2_conv1']['block2_conv1_b_1:0']
#model.layers[4].set_weights = f.layers[7].output

#w,b = f['block2_conv2']['block2_conv2_W_1:0'], f['block2_conv2']['block2_conv2_b_1:0']
#model.layers[5].set_weights = f.layers[11].output

#model.summary()

# %%
opt = Adam(lr=0.0001, decay=1e-5);
es = EarlyStopping(patience=20)
chkpt = ModelCheckpoint(filepath='best_model', save_best_only=True, save_weights_only=True)
model.compile(loss='sparse_categorical_crossentropy',metrics=['accuracy'],optimizer=opt)

# %%
history = model.fit(training_datagen, epochs=75, steps_per_epoch=3663//32,validation_data=testing_datagen,callbacks=[es,chkpt],batch_size=32)
model.save("graph_inception_V3.h5")

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()
plt.show()
# Out:
# Epoch 1/75
# 114/114 [==============================] - 14s 118ms/step - loss: 1.2870 - accuracy: 0.3580 - val_loss: 1.3885 - val_accuracy: 0.2500
# Epoch 2/75
# 114/114 [==============================] - 13s 116ms/step - loss: 0.8498 - accuracy: 0.6317 - val_loss: 1.4765 - val_accuracy: 0.2500
# Epoch 3/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.5986 - accuracy: 0.7366 - val_loss: 1.7739 - val_accuracy: 0.1650
# Epoch 4/75
# 114/114 [==============================] - 13s 116ms/step - loss: 0.4728 - accuracy: 0.8165 - val_loss: 1.8327 - val_accuracy: 0.2025
# Epoch 5/75
# 114/114 [==============================] - 13s 116ms/step - loss: 0.4602 - accuracy: 0.8262 - val_loss: 0.9250 - val_accuracy: 0.5075
# Epoch 6/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.4250 - accuracy: 0.8353 - val_loss: 0.6473 - val_accuracy: 0.6775
# Epoch 7/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.3878 - accuracy: 0.8463 - val_loss: 0.2713 - val_accuracy: 0.9000
# Epoch 8/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.3416 - accuracy: 0.8659 - val_loss: 0.4005 - val_accuracy: 0.8475
# Epoch 9/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.3720 - accuracy: 0.8660 - val_loss: 0.4503 - val_accuracy: 0.8250
# Epoch 10/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.3169 - accuracy: 0.8804 - val_loss: 0.4501 - val_accuracy: 0.8525
# Epoch 11/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.2973 - accuracy: 0.8906 - val_loss: 0.7213 - val_accuracy: 0.7725
# Epoch 12/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.3051 - accuracy: 0.8785 - val_loss: 0.5121 - val_accuracy: 0.8275
# Epoch 13/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.2574 - accuracy: 0.9105 - val_loss: 0.4699 - val_accuracy: 0.8575
# Epoch 14/75
# 114/114 [==============================] - 13s 118ms/step - loss: 0.2370 - accuracy: 0.8983 - val_loss: 0.4376 - val_accuracy: 0.8375
# Epoch 15/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.2341 - accuracy: 0.9029 - val_loss: 0.6966 - val_accuracy: 0.7800
# Epoch 16/75
# 114/114 [==============================] - 13s 118ms/step - loss: 0.3174 - accuracy: 0.8719 - val_loss: 0.3319 - val_accuracy: 0.8800
# Epoch 17/75
# 114/114 [==============================] - 13s 118ms/step - loss: 0.2423 - accuracy: 0.9083 - val_loss: 0.3428 - val_accuracy: 0.8650
# Epoch 18/75
# 114/114 [==============================] - 13s 118ms/step - loss: 0.2397 - accuracy: 0.9082 - val_loss: 0.3638 - val_accuracy: 0.8675
# Epoch 19/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.2369 - accuracy: 0.9021 - val_loss: 0.5697 - val_accuracy: 0.8150
# Epoch 20/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.2421 - accuracy: 0.9058 - val_loss: 0.4509 - val_accuracy: 0.8575
# Epoch 21/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.2082 - accuracy: 0.9119 - val_loss: 0.3894 - val_accuracy: 0.8750
# Epoch 22/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.2182 - accuracy: 0.9214 - val_loss: 0.1453 - val_accuracy: 0.9350
# Epoch 23/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.1976 - accuracy: 0.9197 - val_loss: 0.7470 - val_accuracy: 0.8175
# Epoch 24/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.2046 - accuracy: 0.9159 - val_loss: 0.1533 - val_accuracy: 0.9425
# Epoch 25/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.2149 - accuracy: 0.9197 - val_loss: 0.3567 - val_accuracy: 0.8825
# Epoch 26/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.1765 - accuracy: 0.9436 - val_loss: 0.7554 - val_accuracy: 0.8050
# Epoch 27/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.1988 - accuracy: 0.9267 - val_loss: 0.3168 - val_accuracy: 0.8950
# Epoch 28/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.1409 - accuracy: 0.9543 - val_loss: 0.7414 - val_accuracy: 0.7675
# Epoch 29/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.1892 - accuracy: 0.9238 - val_loss: 0.2625 - val_accuracy: 0.9000
# Epoch 30/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.2085 - accuracy: 0.9118 - val_loss: 0.6768 - val_accuracy: 0.8125
# Epoch 31/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.2194 - accuracy: 0.9132 - val_loss: 0.3225 - val_accuracy: 0.8650
# Epoch 32/75
# 114/114 [==============================] - 14s 120ms/step - loss: 0.1608 - accuracy: 0.9454 - val_loss: 0.1940 - val_accuracy: 0.9100
# Epoch 33/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.1372 - accuracy: 0.9386 - val_loss: 0.7782 - val_accuracy: 0.7850
# Epoch 34/75
# 114/114 [==============================] - 14s 120ms/step - loss: 0.1623 - accuracy: 0.9444 - val_loss: 0.8419 - val_accuracy: 0.8275
# Epoch 35/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.1777 - accuracy: 0.9337 - val_loss: 0.1088 - val_accuracy: 0.9625
# Epoch 36/75
# 114/114 [==============================] - 14s 120ms/step - loss: 0.1349 - accuracy: 0.9520 - val_loss: 0.1488 - val_accuracy: 0.9450
# Epoch 37/75
# 114/114 [==============================] - 19s 163ms/step - loss: 0.1814 - accuracy: 0.9344 - val_loss: 0.2446 - val_accuracy: 0.8900
# Epoch 38/75
# 114/114 [==============================] - 15s 133ms/step - loss: 0.1490 - accuracy: 0.9390 - val_loss: 0.3958 - val_accuracy: 0.8725
# Epoch 39/75
# 114/114 [==============================] - 14s 120ms/step - loss: 0.1673 - accuracy: 0.9479 - val_loss: 0.1952 - val_accuracy: 0.9275
# Epoch 40/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1156 - accuracy: 0.9576 - val_loss: 0.3268 - val_accuracy: 0.9100
# Epoch 41/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1006 - accuracy: 0.9664 - val_loss: 0.9164 - val_accuracy: 0.7850
# Epoch 42/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1175 - accuracy: 0.9584 - val_loss: 0.1934 - val_accuracy: 0.9125
# Epoch 43/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1131 - accuracy: 0.9586 - val_loss: 0.1151 - val_accuracy: 0.9600
# Epoch 44/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1710 - accuracy: 0.9473 - val_loss: 0.1934 - val_accuracy: 0.9225
# Epoch 45/75
# 114/114 [==============================] - 14s 125ms/step - loss: 0.1001 - accuracy: 0.9613 - val_loss: 0.4058 - val_accuracy: 0.8775
# Epoch 46/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.0898 - accuracy: 0.9671 - val_loss: 0.0816 - val_accuracy: 0.9650
# Epoch 47/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1273 - accuracy: 0.9518 - val_loss: 0.2513 - val_accuracy: 0.9125
# Epoch 48/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1170 - accuracy: 0.9630 - val_loss: 0.2483 - val_accuracy: 0.9175
# Epoch 49/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1148 - accuracy: 0.9614 - val_loss: 0.3968 - val_accuracy: 0.8625
# Epoch 50/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1125 - accuracy: 0.9525 - val_loss: 0.1642 - val_accuracy: 0.9400
# Epoch 51/75
# 114/114 [==============================] - 14s 122ms/step - loss: 0.1008 - accuracy: 0.9631 - val_loss: 0.1418 - val_accuracy: 0.9375
# Epoch 52/75
# 114/114 [==============================] - 14s 122ms/step - loss: 0.1501 - accuracy: 0.9422 - val_loss: 0.1931 - val_accuracy: 0.9325
# Epoch 53/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.0944 - accuracy: 0.9640 - val_loss: 0.1468 - val_accuracy: 0.9400
# Epoch 54/75
# 114/114 [==============================] - 14s 122ms/step - loss: 0.0963 - accuracy: 0.9711 - val_loss: 0.1304 - val_accuracy: 0.9450
# Epoch 55/75
# 114/114 [==============================] - 14s 122ms/step - loss: 0.0752 - accuracy: 0.9702 - val_loss: 0.1871 - val_accuracy: 0.9250
# Epoch 56/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.0877 - accuracy: 0.9643 - val_loss: 0.2528 - val_accuracy: 0.9050
# Epoch 57/75
# 114/114 [==============================] - 14s 122ms/step - loss: 0.0923 - accuracy: 0.9687 - val_loss: 0.1372 - val_accuracy: 0.9500
# Epoch 58/75
# 114/114 [==============================] - 14s 122ms/step - loss: 0.1198 - accuracy: 0.9595 - val_loss: 0.1192 - val_accuracy: 0.9500
# Epoch 59/75
# 114/114 [==============================] - 14s 122ms/step - loss: 0.0830 - accuracy: 0.9732 - val_loss: 0.2282 - val_accuracy: 0.9300
# Epoch 60/75
# 114/114 [==============================] - 14s 124ms/step - loss: 0.1393 - accuracy: 0.9493 - val_loss: 0.1477 - val_accuracy: 0.9450
# Epoch 61/75
# 114/114 [==============================] - 14s 123ms/step - loss: 0.0708 - accuracy: 0.9771 - val_loss: 0.2114 - val_accuracy: 0.9125
# Epoch 62/75
# 114/114 [==============================] - 14s 122ms/step - loss: 0.0922 - accuracy: 0.9702 - val_loss: 0.2616 - val_accuracy: 0.9025
# Epoch 63/75
# 114/114 [==============================] - 14s 123ms/step - loss: 0.0670 - accuracy: 0.9784 - val_loss: 0.2225 - val_accuracy: 0.9175
# Epoch 64/75
# 114/114 [==============================] - 14s 123ms/step - loss: 0.0767 - accuracy: 0.9731 - val_loss: 0.0994 - val_accuracy: 0.9650
# Epoch 65/75
# 114/114 [==============================] - 14s 123ms/step - loss: 0.1067 - accuracy: 0.9529 - val_loss: 0.4191 - val_accuracy: 0.8700
# Epoch 66/75
# 114/114 [==============================] - 14s 122ms/step - loss: 0.1151 - accuracy: 0.9534 - val_loss: 0.0870 - val_accuracy: 0.9675
