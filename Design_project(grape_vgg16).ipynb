# %%
import os
import glob
import h5py
import shutil
import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mimg
from os import listdir, makedirs, getcwd, remove
from os.path import isfile, join, abspath, exists, isdir, expanduser
from PIL import Image
from pathlib import Path
from skimage.io import imread
from skimage.transform import resize
from keras.models import Sequential, Model
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from keras.layers import GlobalMaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.merge import Concatenate
from keras.models import Model
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
import cv2
from keras import backend as K

# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt

from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras_preprocessing.image import ImageDataGenerator


dir = "E:\Design Project Dataset\Grape Dataset"

train_dir = os.path.join(dir, 'train')
test_dir = os.path.join(dir, 'test')

CATEGORIES = ['Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___healthy', 'Grape___healthy']

train_dataset_size = 0
test_dataset_size = 0

for i in CATEGORIES:
    train_dataset_size += len(os.listdir(os.path.join(train_dir, i)))
    test_dataset_size += len(os.listdir(os.path.join(test_dir, i)))


train_image_generator = ImageDataGenerator(rescale=1./255, rotation_range=45, width_shift_range=.15, height_shift_range=.15, horizontal_flip=True, zoom_range=0.5)
validation_image_generator = ImageDataGenerator(rescale=1./255)

training_datagen = train_image_generator.flow_from_directory(batch_size=16, directory=train_dir, shuffle=True, target_size=(256, 256), class_mode='sparse')

testing_datagen = validation_image_generator.flow_from_directory(batch_size=16, directory=test_dir, shuffle=True, target_size=(256, 256), class_mode='sparse')
# Out:
# Found 3663 images belonging to 4 classes.
# Found 400 images belonging to 4 classes.

# %%
def build_model():
    input_img = Input(shape=(256,256,3), name='ImageInput')
    x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv1_1')(input_img)
    x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv1_2')(x)
    x = MaxPooling2D((2,2), name='pool1')(x)

    x = SeparableConv2D(128, (3,3), activation='relu', padding='same', name='Conv2_1')(x)
    x = SeparableConv2D(128, (3,3), activation='relu', padding='same', name='Conv2_2')(x)
    x = MaxPooling2D((2,2), name='pool2')(x)

    x = SeparableConv2D(256, (3,3), activation='relu', padding='same', name='Conv3_1')(x)
    x = BatchNormalization(name='bn1')(x)
    x = SeparableConv2D(256, (3,3), activation='relu', padding='same', name='Conv3_2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = SeparableConv2D(256, (3,3), activation='relu', padding='same', name='Conv3_3')(x)
    x = MaxPooling2D((2,2), name='pool3')(x)

    x = SeparableConv2D(512, (3,3), activation='relu', padding='same', name='Conv4_1')(x)
    x = BatchNormalization(name='bn3')(x)
    x = SeparableConv2D(128, (3,3), activation='relu', padding='same', name='Conv4_2')(x)
    x = BatchNormalization(name='bn4')(x)
    x = SeparableConv2D(64, (3,3), activation='relu', padding='same', name='Conv4_3')(x)
    x = MaxPooling2D((2,2), name='pool4')(x)

    x = Flatten(name='flatten')(x)
    x = Dense(64, activation='relu', name='fc1')(x)
    x = Dropout(0.7, name='dropout1')(x)
    x = Dense(32, activation='relu', name='fc2')(x)
    x = Dropout(0.5, name='dropout2')(x)
    x = Dense(4, activation='softmax', name='fc3')(x)

    model = Model(inputs=input_img, outputs=x)
    return model

# %%
def build_small_model():
    input_img = Input(shape=(256,256,3), name='ImageInput')
    x = Conv2D(64,(3,3),activation='relu',padding='same',name='Conv1')(input_img)
    x = BatchNormalization(name='bn1')(x)
    x = MaxPooling2D((2,2),name='pool1')(x)

    x= SeparableConv2D(128,(3,3),activation='relu',padding='same',name='Conv2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = MaxPooling2D((2,2), name='pool2')(x)

    x = SeparableConv2D(256,(3,3),activation='relu',padding='same',name='Conv3')(x)

    x = SeparableConv2D(256,(3,3), activation='relu',padding='same', name='Conv4')(x)

    x = SeparableConv2D(256,(3,3), activation='relu', padding='same', name='Conv5')(x)
    x = MaxPooling2D((2,2), name='pool3')(x)

    x = Flatten(name='flatten')(x)
    x = Dense(64,activation='relu',name='fc1')(x)
    x = Dense(32,activation='relu',name='fc2')(x)
    x = Dense(4,activation='softmax',name='fc3')(x)

    small_model = Model(inputs=input_img, outputs=x)

    return small_model

# %%
model =  build_small_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# ImageInput (InputLayer)      [(None, 256, 256, 3)]     0
# _________________________________________________________________
# Conv1 (Conv2D)               (None, 256, 256, 64)      1792
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 256, 256, 64)      256
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 128, 128, 64)      0
# _________________________________________________________________
# Conv2 (SeparableConv2D)      (None, 128, 128, 128)     8896
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 128, 128, 128)     512
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 64, 64, 128)       0
# _________________________________________________________________
# Conv3 (SeparableConv2D)      (None, 64, 64, 256)       34176
# _________________________________________________________________
# Conv4 (SeparableConv2D)      (None, 64, 64, 256)       68096
# _________________________________________________________________
# Conv5 (SeparableConv2D)      (None, 64, 64, 256)       68096
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 32, 32, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 262144)            0
# _________________________________________________________________
# fc1 (Dense)                  (None, 64)                16777280
# _________________________________________________________________
# fc2 (Dense)                  (None, 32)                2080
# _________________________________________________________________
# fc3 (Dense)                  (None, 4)                 132
# =================================================================
# Total params: 16,961,316
# Trainable params: 16,960,932
# Non-trainable params: 384
# _________________________________________________________________

# %%
# Open the VGG16 weight file
f = keras.applications.VGG16(weights='imagenet', include_top=True)

# %%
# Select the layers for which you want to set weight.

#w,b = f['block1_conv1']['block1_conv1_W_1:0'], f['block1_conv1']['block1_conv1_b_1:0']
model.layers[1].set_weights = f.layers[1].output

#w,b = f['block1_conv2']['block1_conv2_W_1:0'], f['block1_conv2']['block1_conv2_b_1:0']
model.layers[2].set_weights = f.layers[4].output

#w,b = f['block2_conv1']['block2_conv1_W_1:0'], f['block2_conv1']['block2_conv1_b_1:0']
#model.layers[4].set_weights = f.layers[7].output

#w,b = f['block2_conv2']['block2_conv2_W_1:0'], f['block2_conv2']['block2_conv2_b_1:0']
#model.layers[5].set_weights = f.layers[11].output

#model.summary()

# %%
opt = Adam(lr=0.0001, decay=1e-5)
es = EarlyStopping(patience=20)
chkpt = ModelCheckpoint(filepath='best_model', save_best_only=True, save_weights_only=True)
model.compile(loss='sparse_categorical_crossentropy',metrics=['accuracy'],optimizer=opt)

# %%
history = model.fit(training_datagen, epochs=75, steps_per_epoch=3663//32,validation_data=testing_datagen,callbacks=[es,chkpt],batch_size=32)
model.save("graph_grape_vgg16.h5")

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()
plt.show()
# Out:
# Epoch 1/75
# 114/114 [==============================] - 16s 122ms/step - loss: 1.3027 - accuracy: 0.3585 - val_loss: 1.3892 - val_accuracy: 0.2500
# Epoch 2/75
# 114/114 [==============================] - 13s 116ms/step - loss: 0.9275 - accuracy: 0.5784 - val_loss: 1.4376 - val_accuracy: 0.2500
# Epoch 3/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.7286 - accuracy: 0.6995 - val_loss: 1.4797 - val_accuracy: 0.2500
# Epoch 4/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.5947 - accuracy: 0.7300 - val_loss: 1.5175 - val_accuracy: 0.2725
# Epoch 5/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.4540 - accuracy: 0.8278 - val_loss: 1.7308 - val_accuracy: 0.2600
# Epoch 6/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.4239 - accuracy: 0.8469 - val_loss: 0.4457 - val_accuracy: 0.8125
# Epoch 7/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.3274 - accuracy: 0.8673 - val_loss: 0.4960 - val_accuracy: 0.8425
# Epoch 8/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.3269 - accuracy: 0.8670 - val_loss: 0.5062 - val_accuracy: 0.8350
# Epoch 9/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.3174 - accuracy: 0.8743 - val_loss: 0.4177 - val_accuracy: 0.8575
# Epoch 10/75
# 114/114 [==============================] - 13s 117ms/step - loss: 0.2956 - accuracy: 0.8763 - val_loss: 0.4134 - val_accuracy: 0.8675
# Epoch 11/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.2405 - accuracy: 0.9155 - val_loss: 0.6556 - val_accuracy: 0.8350
# Epoch 12/75
# 114/114 [==============================] - 13s 118ms/step - loss: 0.2630 - accuracy: 0.8985 - val_loss: 0.6071 - val_accuracy: 0.8525
# Epoch 13/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.2790 - accuracy: 0.8865 - val_loss: 0.7608 - val_accuracy: 0.8075
# Epoch 14/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.2314 - accuracy: 0.9135 - val_loss: 0.4284 - val_accuracy: 0.8725
# Epoch 15/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.2355 - accuracy: 0.9123 - val_loss: 0.6185 - val_accuracy: 0.8300
# Epoch 16/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.2081 - accuracy: 0.9207 - val_loss: 0.6733 - val_accuracy: 0.8500
# Epoch 17/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.2145 - accuracy: 0.9253 - val_loss: 1.0751 - val_accuracy: 0.7625
# Epoch 18/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.2177 - accuracy: 0.9183 - val_loss: 0.1966 - val_accuracy: 0.9175
# Epoch 19/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.2081 - accuracy: 0.9261 - val_loss: 0.6476 - val_accuracy: 0.8000
# Epoch 20/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.2067 - accuracy: 0.9127 - val_loss: 0.6738 - val_accuracy: 0.8325
# Epoch 21/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.1994 - accuracy: 0.9344 - val_loss: 0.1971 - val_accuracy: 0.9300
# Epoch 22/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.2082 - accuracy: 0.9157 - val_loss: 0.2751 - val_accuracy: 0.9175
# Epoch 23/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.1948 - accuracy: 0.9279 - val_loss: 0.5722 - val_accuracy: 0.8425
# Epoch 24/75
# 114/114 [==============================] - 14s 118ms/step - loss: 0.1880 - accuracy: 0.9236 - val_loss: 0.5006 - val_accuracy: 0.8500
# Epoch 25/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.1825 - accuracy: 0.9342 - val_loss: 0.5018 - val_accuracy: 0.8775
# Epoch 26/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.1758 - accuracy: 0.9425 - val_loss: 0.4593 - val_accuracy: 0.8550
# Epoch 27/75
# 114/114 [==============================] - 14s 119ms/step - loss: 0.1694 - accuracy: 0.9337 - val_loss: 0.5023 - val_accuracy: 0.8300
# Epoch 28/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1669 - accuracy: 0.9243 - val_loss: 0.5384 - val_accuracy: 0.8300
# Epoch 29/75
# 114/114 [==============================] - 14s 123ms/step - loss: 0.1671 - accuracy: 0.9444 - val_loss: 0.2311 - val_accuracy: 0.9225
# Epoch 30/75
# 114/114 [==============================] - 14s 124ms/step - loss: 0.1456 - accuracy: 0.9351 - val_loss: 0.6405 - val_accuracy: 0.8175
# Epoch 31/75
# 114/114 [==============================] - 14s 124ms/step - loss: 0.1289 - accuracy: 0.9550 - val_loss: 0.1276 - val_accuracy: 0.9450
# Epoch 32/75
# 114/114 [==============================] - 14s 123ms/step - loss: 0.1498 - accuracy: 0.9453 - val_loss: 0.3838 - val_accuracy: 0.8675
# Epoch 33/75
# 114/114 [==============================] - 14s 124ms/step - loss: 0.1360 - accuracy: 0.9466 - val_loss: 0.3246 - val_accuracy: 0.8925
# Epoch 34/75
# 114/114 [==============================] - 14s 123ms/step - loss: 0.1631 - accuracy: 0.9396 - val_loss: 0.5391 - val_accuracy: 0.8425
# Epoch 35/75
# 114/114 [==============================] - 14s 122ms/step - loss: 0.1279 - accuracy: 0.9483 - val_loss: 0.2314 - val_accuracy: 0.9175
# Epoch 36/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1491 - accuracy: 0.9473 - val_loss: 0.4076 - val_accuracy: 0.8750
# Epoch 37/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1888 - accuracy: 0.9374 - val_loss: 0.5863 - val_accuracy: 0.8275
# Epoch 38/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1134 - accuracy: 0.9611 - val_loss: 0.6244 - val_accuracy: 0.8075
# Epoch 39/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1603 - accuracy: 0.9421 - val_loss: 0.2558 - val_accuracy: 0.9225
# Epoch 40/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1100 - accuracy: 0.9613 - val_loss: 0.1568 - val_accuracy: 0.9450
# Epoch 41/75
# 114/114 [==============================] - 14s 122ms/step - loss: 0.1089 - accuracy: 0.9495 - val_loss: 0.6774 - val_accuracy: 0.8050
# Epoch 42/75
# 114/114 [==============================] - 14s 121ms/step - loss: 0.1382 - accuracy: 0.9503 - val_loss: 0.1471 - val_accuracy: 0.9500
# Epoch 43/75
# 114/114 [==============================] - 14s 122ms/step - loss: 0.1187 - accuracy: 0.9604 - val_loss: 0.4914 - val_accuracy: 0.9075
# Epoch 44/75
# 114/114 [==============================] - 14s 123ms/step - loss: 0.1064 - accuracy: 0.9616 - val_loss: 0.2418 - val_accuracy: 0.9100
# Epoch 45/75
# 114/114 [==============================] - 14s 123ms/step - loss: 0.1763 - accuracy: 0.9369 - val_loss: 0.5540 - val_accuracy: 0.8150
# Epoch 46/75
# 114/114 [==============================] - 14s 125ms/step - loss: 0.0993 - accuracy: 0.9618 - val_loss: 0.1356 - val_accuracy: 0.9450
# Epoch 47/75
# 114/114 [==============================] - 15s 127ms/step - loss: 0.0922 - accuracy: 0.9656 - val_loss: 0.7022 - val_accuracy: 0.8550
# Epoch 48/75
# 114/114 [==============================] - 14s 125ms/step - loss: 0.1079 - accuracy: 0.9622 - val_loss: 0.4743 - val_accuracy: 0.8700
# Epoch 49/75
# 114/114 [==============================] - 14s 125ms/step - loss: 0.0905 - accuracy: 0.9678 - val_loss: 0.4123 - val_accuracy: 0.8875
# Epoch 50/75
# 114/114 [==============================] - 14s 122ms/step - loss: 0.0964 - accuracy: 0.9668 - val_loss: 0.3831 - val_accuracy: 0.8725
# Epoch 51/75
# 114/114 [==============================] - 14s 122ms/step - loss: 0.0914 - accuracy: 0.9711 - val_loss: 0.2066 - val_accuracy: 0.9250
